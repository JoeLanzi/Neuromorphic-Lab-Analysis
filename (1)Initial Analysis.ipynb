# %%
import numpy as np
import matplotlib.pyplot as plt
import csv

address = r'C:\Users\joela\Desktop\LanziPython/test.csv' #csv file address
start_time = 0 ## start of array 
end_time = 0 ## end of array 
on_off=[] ## array for on/off neuromorphic camera values
timestamp=[] ## array for timestamp value of camera samples

with open(address) as csvfile:
    spamreader = csv.reader(csvfile, delimiter=',')
    for row in spamreader:
        on_off.append(row[0])
        timestamp.append(row[1])
        try:
            on_off[-1]=int(on_off[-1])
            timestamp[-1]=int(timestamp[-1])
        except:
            continue

## grab header values from csv
eventTitle=on_off.pop(0)
timeStampTitle=timestamp.pop(0)

## remove stray startup value.. maybe
## del on_off[0:2]
## del timestamp[0:2]

## normalize time stamps
first_time=timestamp[0]
for x in range(len(timestamp)):
    timestamp[x]=timestamp[x]-first_time

# %%
## extracting one period from data
one_period = [i for i in timestamp if i < 28500]    
end_time = len(one_period)

# %%
# Out:
# <img src="data:image/png;base64,..." width="976">

# %%
def value(x,y): #this looks for similar values within a certain time period
    for i in range(0,len(y)-1):
        if x[i:i+2] == [1,1] and (y[i+1] - y[i]) >= 1:
            print (f"True from {i+2} to {i+3} events")
        else:
            print(f"False from {i+2} to {i+3} events")

# %%
for n,i in enumerate(on_off): #Converting the list(value of -1 to 0) to Binary
    if i == -1:
        on_off[n] = 0

# %%
#Converting On_Off Events to Binary to Decimal
decimal_list = [] 
for i in range(0,len(one_period)-8,8):
    i = "0b" + ''.join(map(str,on_off[(i):(i+8)]))
    
    decimal_list.append(int(i,2))

#Converting On_Off Events to Binary
bin_list = [] 
for i in range(0,len(one_period)-8,8):
    i = "0b" + ''.join(map(str,on_off[(i):(i+8)]))
    
    bin_list.append(i)

# %%
one_period = [i for i in timestamp if i < 28500] 
second_period = [i for i in timestamp if i > 28500 and i <57000]
third_period = [i for i in timestamp if i > 57000 and i <85500]
fourth_period = [i for i in timestamp if i > 85500 and i <114000]

print(len(one_period))
print(len(second_period))
print(len(third_period))
print(len(fourth_period))
# Out:
# 143
# 166
# 130
# 166

# %%
decimal_list2 = [] 
for i in range(len(one_period),len(one_period)+len(second_period)-8,8):
    i = "0b" + ''.join(map(str,on_off[(i):(i+8)]))
    
    decimal_list2.append(int(i,2))\
    
decimal_list3 = [] 
for i in range(len(one_period)+len(second_period),len(one_period)+len(second_period)+len(third_period)-8,8):
    i = "0b" + ''.join(map(str,on_off[(i):(i+8)]))
    
    decimal_list3.append(int(i,2))

decimal_list4 = [] 
for i in range(len(one_period)+len(second_period)+len(third_period),len(one_period)+len(second_period)+len(third_period)+len(fourth_period)-8,8):
    i = "0b" + ''.join(map(str,on_off[(i):(i+8)]))
    
    decimal_list4.append(int(i,2))

# %%
print(decimal_list)
print(decimal_list2)
print(decimal_list3)
print(decimal_list4)
# Out:
# [40, 0, 0, 176, 12, 219, 159, 214, 143, 207, 128, 10, 45, 95, 47, 164, 88]
# [96, 1, 5, 24, 40, 239, 87, 4, 4, 128, 96, 80, 1, 96, 0, 72, 64, 0, 17, 28]
# [1, 64, 224, 40, 55, 50, 49, 3, 96, 32, 123, 127, 231, 57, 196, 0]
# [64, 0, 132, 0, 49, 191, 217, 28, 198, 217, 164, 197, 75, 38, 84, 2, 32, 0, 168, 76]

# %%
bin_list2 = [] 
for i in range(len(one_period),len(one_period)+len(second_period)-8,8):
    i = "0b" + ''.join(map(str,on_off[(i):(i+8)]))
    
    bin_list2.append(i)
    
bin_list3 = [] 
for i in range(len(one_period)+len(second_period),len(one_period)+len(second_period)+len(third_period)-8,8):
    i = "0b" + ''.join(map(str,on_off[(i):(i+8)]))
    
    bin_list3.append(i)

bin_list4 = [] 
for i in range(len(one_period)+len(second_period)+len(third_period),len(one_period)+len(second_period)+len(third_period)+len(fourth_period)-8,8):
    i = "0b" + ''.join(map(str,on_off[(i):(i+8)]))
    
    bin_list4.append(i)

# %%
print(bin_list[0:9])
print(bin_list2[0:9])
print(bin_list3[0:9])
print(bin_list4[0:9])
# Out:
# ['0b00101000', '0b00000000', '0b00000000', '0b10110000', '0b00001100', '0b11011011', '0b10011111', '0b11010110', '0b10001111']
# ['0b01100000', '0b00000001', '0b00000101', '0b00011000', '0b00101000', '0b11101111', '0b01010111', '0b00000100', '0b00000100']
# ['0b00000001', '0b01000000', '0b11100000', '0b00101000', '0b00110111', '0b00110010', '0b00110001', '0b00000011', '0b01100000']
# ['0b01000000', '0b00000000', '0b10000100', '0b00000000', '0b00110001', '0b10111111', '0b11011001', '0b00011100', '0b11000110']

# %%
def value(x):
    for i in range(0,len(x)-1):
        if x[i:i+4] == [0,0,1,0]:
            print (f"True from {i+1} to {i+4} events")

# %%
one_period = [i for i in timestamp if i < 28500] 
end = len(one_period)

# %%
r1 = dict(zip(timestamp[:end],on_off[:end]))
r2 = dict(zip(timestamp[:end],on_off[:end]))

# %%
answer = list((set(r1.items()) & set(r2.items())))
answer.sort()
len(answer)
# Out:
# 138

# %%
(len(answer)/len(one_period))*100
# Out:
# 96.5034965034965
